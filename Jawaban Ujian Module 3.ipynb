# %% [markdown]
# ## 1. Import Libraries (pandas,numpy,matplotlib.pyplot,seaborn) and set %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## 2. Import Data creditcard.csv and show the top 5 data

# %%
dfcredit = pd.read_csv('creditcard.csv')

# %%
dfcredit.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %% [markdown]
# ## 3. Show the info of the dataframe

# %%
dfcredit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %% [markdown]
# ## 4. Show the describe of the dataframe

# %%
dfcredit.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %% [markdown]
# ## 5. Show info table of the DF like this

# %%
items = {
    'dataFeatures' : [i for i in dfcredit.columns],
    'dataType' : [i for i in dfcredit.dtypes],
    'null' : [i for i in dfcredit.isnull().sum()],
    'nullPct' : [i for i in (dfcredit.isnull().sum() * 100 / len(dfcredit)).round(2)],
    'unique' : [i for i in dfcredit.nunique()],
    'uniqueSample' : [list(dfcredit[i].drop_duplicates().sample(2).values) for i in dfcredit.columns]
}

df1 = pd.DataFrame(items)
df1
# Out:
#    dataFeatures dataType  null  nullPct  unique  \
# 0          Time  float64     0      0.0  124592
# 1            V1  float64     0      0.0  275663
# 2            V2  float64     0      0.0  275663
# 3            V3  float64     0      0.0  275663
# 4            V4  float64     0      0.0  275663
# 5            V5  float64     0      0.0  275663
# 6            V6  float64     0      0.0  275663
# 7            V7  float64     0      0.0  275663
# 8            V8  float64     0      0.0  275663
# 9            V9  float64     0      0.0  275663
# 10          V10  float64     0      0.0  275663
# 11          V11  float64     0      0.0  275663
# 12          V12  float64     0      0.0  275663
# 13          V13  float64     0      0.0  275663
# 14          V14  float64     0      0.0  275663
# 15          V15  float64     0      0.0  275663
# 16          V16  float64     0      0.0  275663
# 17          V17  float64     0      0.0  275663
# ...

# %% [markdown]
# ## 6. Do Standard Scaler for all variable except the target

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(dfcredit.drop('Class',axis=1))
scaled_features = scaler.transform(dfcredit.drop('Class',axis=1))
df_feat = pd.DataFrame(scaled_features,columns=dfcredit.columns[:-1])
df_feat['Class'] = dfcredit['Class']
df_feat.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1 -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2 -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3 -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4 -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
#
#          V7        V8        V9  ...         V21       V22       V23  \
# 0  0.193679  0.082637  0.331128  ...   -0.024923  0.382854 -0.176911
# 1 -0.063700  0.071253 -0.232494  ...   -0.307377 -0.880077  0.162201
# 2  0.639776  0.207373 -1.378675  ...    0.337632  1.063358  1.456320
# 3  0.192071  0.316018 -1.262503  ...   -0.147443  0.007267 -0.304777
# 4  0.479302 -0.226510  0.744326  ...   -0.012839  1.100011 -0.220123
#
#         V24       V25       V26       V27       V28    Amount  Class
# ...

# %% [markdown]
# ## 7. Do PCA for the features to make it only 10 features remaining

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
pca.fit(scaled_features)
x_pca = pca.transform(scaled_features)
x_pca.shape
# Out:
# (284807, 10)

# %% [markdown]
# #### and go make the data dataframe results of the PCA like below

# %%
dfpca = pd.DataFrame(x_pca,columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10'])
dfpca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  0.402315 -2.506127  0.210269  0.550903 -0.445784 -0.474947  0.734241
# 1 -0.396988 -2.109065  0.000733 -0.348741  0.630726  0.279818 -0.276846
# 2  1.749005 -2.474616 -0.948114  0.675148  0.859996 -0.997914 -0.131081
# 3  0.300617 -1.812402 -1.696781 -0.346141 -0.366865 -1.029415 -0.234645
# 4 -0.030702 -1.482111  0.025959 -0.012278 -0.595728 -0.401997  0.492038
#
#         PC8       PC9      PC10
# 0  0.996406  0.715247 -0.354365
# 1 -0.150696 -0.181781  1.097048
# 2  0.488844  0.501685 -0.728073
# 3 -0.137709  0.042528  0.707020
# 4 -0.156030  0.521487  0.684349

# %%
dfpca['Class'] = dfcredit['Class']

# %% [markdown]
# ## 8. Make target series dan show it value_counts in text and seaborn countplot, and pairplot

# %%
df_feat['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
sns.countplot(x="Class", data=df_feat)

# %% [markdown]
# ### Use PCA again to make dataframe for pairplot with just 2 PC only from PCA Dataframe you just make at no. 7, and then just take 5000 sample to make the pairplot using .sample()

# %%
pca = PCA(n_components=2)
pca.fit(scaled_features)
x_pca = pca.transform(scaled_features)
x_pca.shape
# Out:
# (284807, 2)

# %%
dfpca5k = pd.DataFrame(x_pca,columns=['PC1','PC2'])
dfpca5k['Class'] = dfcredit['Class']
dfpca5k.head()
# Out:
#         PC1       PC2  Class
# 0  0.419106 -2.523359      0
# 1 -0.393001 -2.072343      0
# 2  1.871588 -2.498794      0
# 3  0.316274 -1.768151      0
# 4 -0.001996 -1.485129      0

# %%
from random import sample 
dfpca5k = dfpca5k.sample(n=5000, replace=False)

# %%
sns.pairplot(dfpca5k, hue='Class',diag_kind="kde")
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# ## 9. Use K Fold (K=5,shuffle=True,random_state=42), every loop use RandomOverSampler for the training data, and then use GradientBoostingClassifier for the model

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
data = dfpca.drop(['Class'], axis=1)
target = dfpca['Class']

# %%
def calc_train_error(X_train, y_train, model):
    # Return in-sample error for already fit model
    predictions = model.predict(X_train)
    predictProba = model.predict_proba(X_train) # buat roc_auc disini
    matt = matthews_corrcoef(y_train, predictions)
    f1 = f1_score(y_train, predictions, average='macro')
    report = classification_report(y_train,predictions)
    roc_auc = roc_auc_score(y_train, predictProba[:,1])
    accuracy = accuracy_score(y_train, predictions)
    confMatrix = confusion_matrix(y_train, predictions)
    logloss = log_loss(y_train, predictProba)
    return {
        'report' : report,
        'matthew' : matt,
        'f1' : f1,
        'roc' : roc_auc,
        'accuracy' : accuracy,
        'confusion' : confMatrix,
        'logloss' : logloss
    }

def calc_validation_error(X_test, y_test, model):
    # Return out-of-sample error for already fit model
    predictions = model.predict(X_test)
    predictProba = model.predict_proba(X_test)
    matt = matthews_corrcoef(y_test, predictions)
    f1 = f1_score(y_test, predictions, average='macro')
    report = classification_report(y_test,predictions)
    roc_auc = roc_auc_score(y_test, predictProba[:,1])
    accuracy = accuracy_score(y_test, predictions)
    confMatrix = confusion_matrix(y_test, predictions)
    logloss = log_loss(y_test, predictProba)
    return {
        'report' : report,
        'matthew' : matt,
        'f1' : f1,
        'roc' : roc_auc,
        'accuracy' : accuracy,
        'confusion' : confMatrix,
        'logloss' : logloss
    }

def calc_metrics(X_train, y_train, X_test, y_test, model):
    # Fits model and returns the classification matrix for in-sample error and out-of-sample error
    model.fit(X_train, y_train)
    train_error = calc_train_error(X_train, y_train, model)
    validation_error = calc_validation_error(X_test, y_test, model)
    return train_error, validation_error

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score, matthews_corrcoef, f1_score, log_loss
from imblearn.over_sampling import RandomOverSampler

# %%
train_errors = []
validation_errors = []

for train_index, val_index in kf.split(data,target):
    #split data
    X_train, X_val = data.iloc[train_index], data.iloc[val_index]
    y_train, y_val = target.iloc[train_index], target.iloc[val_index]
    
    # RANDOM OVER SAMPLER
    ros = RandomOverSampler()
    X_ros, y_ros = ros.fit_sample(X_train, y_train)
    
    #instantiate model
    gbc = GradientBoostingClassifier()
    
    #calculate errors
    train_error, val_error = calc_metrics(X_ros, y_ros, X_val, y_val, gbc)
    
    #append to appropriate list
    train_errors.append(train_error)
    validation_errors.append(val_error)

# %% [markdown]
# ## 10. Print the Model Evaluation like below from the K Fold

# %%
listItem = []
listIndex = []

for i,t,v in zip(range(1,len(train_errors)+1),train_errors, validation_errors):
    listItem.append([t['accuracy'], v['accuracy'], t['roc'], v['roc'], t['f1'], v['f1'], t['matthew'], v['matthew'], t['logloss'], v['logloss']])
    listIndex.append(i)
                
dfEvaluate = pd.DataFrame(listItem ,columns=['Train Accuracy', 'Test Accuracy', 'Train ROC AUC', 'Test ROC AUC', 'Train F1 Score', 'Test F1 Score', 'Train Matthews Corr Coef', 'Test Matthews Corr Coef', 'Train Log Loss', 'Test Log Loss'],index = listIndex)
dfEvaluate
# Out:
#    Train Accuracy  Test Accuracy  Train ROC AUC  Test ROC AUC  Train F1 Score  \
# 1        0.979673       0.988589       0.998620      0.976515        0.979671
# 2        0.975513       0.985376       0.998058      0.952544        0.975510
# 3        0.978342       0.991099       0.999054      0.945324        0.978339
# 4        0.974925       0.989695       0.998762      0.962353        0.974919
# 5        0.981733       0.985938       0.998239      0.967785        0.981733
#
#    Test F1 Score  Train Matthews Corr Coef  Test Matthews Corr Coef  \
# 1       0.600785                  0.959517                 0.317167
# 2       0.576876                  0.951247                 0.273835
# 3       0.613088                  0.957015                 0.326157
# 4       0.610713                  0.950265                 0.331284
# 5       0.591499                  0.963514                 0.305851
#
#    Train Log Loss  Test Log Loss
# 1        0.083270       0.079648
# ...

# %%
print("Avg Accuracy Train : {}".format((list(np.mean(listItem, axis=0)))[0]))
print("Avg Accuracy Validation : {}".format((list(np.mean(listItem, axis=0)))[1]))
print("Avg ROC AUC Train : {}".format((list(np.mean(listItem, axis=0)))[2]))
print("Avg ROC AUC Validation : {}".format((list(np.mean(listItem, axis=0)))[3]))
# Out:
# Avg Accuracy Train : 0.978037098703919
# Avg Accuracy Validation : 0.9881393445862974
# Avg ROC AUC Train : 0.9985465125387856
# Avg ROC AUC Validation : 0.9609043704835051

# %% [markdown]
# #### Training Errors Classification Reports

# %%
for tr_err in train_errors:
    print(tr_err['report'])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98    227451
#            1       0.99      0.97      0.98    227451
#
#    micro avg       0.98      0.98      0.98    454902
#    macro avg       0.98      0.98      0.98    454902
# weighted avg       0.98      0.98      0.98    454902
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98    227446
#            1       0.99      0.96      0.98    227446
#
#    micro avg       0.98      0.98      0.98    454892
#    macro avg       0.98      0.98      0.98    454892
# weighted avg       0.98      0.98      0.98    454892
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98    227449
#            1       0.99      0.97      0.98    227449
#
#    micro avg       0.98      0.98      0.98    454898
#    macro avg       0.98      0.98      0.98    454898
# ...

# %% [markdown]
# #### Validation Errors Classification Reports

# %%
for val_err in validation_errors:
    print(val_err['report'])
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56864
#            1       0.12      0.87      0.21        98
#
#    micro avg       0.99      0.99      0.99     56962
#    macro avg       0.56      0.93      0.60     56962
# weighted avg       1.00      0.99      0.99     56962
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56869
#            1       0.09      0.86      0.16        93
#
#    micro avg       0.99      0.99      0.99     56962
#    macro avg       0.54      0.92      0.58     56962
# weighted avg       1.00      0.99      0.99     56962
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56866
#            1       0.13      0.80      0.23        95
#
#    micro avg       0.99      0.99      0.99     56961
#    macro avg       0.57      0.90      0.61     56961
# ...

# %% [markdown]
# ### Print Features Importance

# %%
coef1 = pd.Series(gbc.feature_importances_, X_train.columns).sort_values(ascending=False).head(10)
coef1.plot(kind='bar', title='Feature Importance')

# %% [markdown]
# ## Goodluck Guys! Salam Bertasbih!
